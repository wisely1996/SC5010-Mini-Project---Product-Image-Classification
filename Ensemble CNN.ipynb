# %%
import keras
import pandas as pd
import numpy as np 
import itertools

from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img 
from keras.models import Sequential 
from keras import optimizers
from keras.preprocessing import image
from keras.layers import Dropout, Flatten, Dense 
from keras import applications 
from keras.utils.np_utils import to_categorical 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
# %matplotlib inline
import math 
import datetime
import time
import tensorflow as tf

# %%
from sklearn.model_selection import train_test_split

df = pd.read_csv("train.csv")
df_top = df[(df["category"] == 3)|(df["category"] == 28)]
df_top.loc[:,"class"] = 0
df_btm = df[(df["category"] == 4)|(df["category"] == 29)]
df_btm.loc[:,"class"] = 1

df_cloth = pd.concat([df_top,df_btm]).reset_index(drop = True)
df_cloth

X = df_cloth[["filename","category"]]
y = pd.DataFrame(df_cloth["class"])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 5010)

X_train
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14628\3930989819.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_top.loc[:,"class"] = 0
# C:\Users\User\AppData\Local\Temp\ipykernel_14628\3930989819.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_btm.loc[:,"class"] = 1
#                                   filename  category
# 9817  6ed9c2a655d6f84badb557bc210c1fb5.jpg        29
# 234   293c5038f681f017254800819a968212.jpg         3
# 8238  90e1e6fbaa0c9a69ad0ee70bc2ea251d.jpg        29
# 2708  42ea56b9983ba2bf7e01acf5dda172f5.jpg        28
# 7671  f13b80836fbe7c635a9817e121093594.jpg         4
# ...                                    ...       ...
# 9880  b61f5b0aec4375090b5a268a1f516ead.jpg        29
# 2601  5072c6fb5ab3ae57524639805321a0f4.jpg         3
# 2018  b2afaca110148bc0710f828c9d53b39f.jpg         3
# 6834  3511390df751f1c8c70ca9c6897ddfc5.jpg         4
# 9306  026f054380bff76064f26bcb2628ff40.jpg        29
#
# [9094 rows x 2 columns]

# %%
X1 = X_train[["filename","category"]]
y1 = pd.DataFrame(y_train["class"])

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size = 0.2, random_state = 5010)
X1_train.shape, X1_test.shape, y1_train.shape, y1_test.shape
# Out:
# ((7275, 2), (1819, 2), (7275, 1), (1819, 1))

# %%
import os

train_path1 = "train_dataset"
validation_path1 = "validation_dataset"

len(os.listdir(train_path1 + '/top')), len(os.listdir(train_path1 + '/btm')), len(os.listdir(validation_path1 + '/top')), len(os.listdir(validation_path1 + '/btm'))
# Out:
# (3803, 3472, 957, 862)

# %%
IMG_SIZE = (299, 299)
shift = 0.2

training_datagen1 = ImageDataGenerator(
      rescale = 1./255,
      rotation_range=5,
      brightness_range=[0.2,1.5],
      width_shift_range=shift, 
      height_shift_range=shift,
      horizontal_flip=True)
train_set1 = training_datagen1.flow_from_directory(
     train_path1,
     seed=9,
	   target_size=IMG_SIZE,
     class_mode = "categorical")
validation_datagen1 = ImageDataGenerator(
      rescale = 1./255)
val_set1 = validation_datagen1.flow_from_directory(
	  validation_path1,
	  target_size=IMG_SIZE,
    shuffle=False,
    seed=9,
    class_mode = "categorical")
# Out:
# Found 7275 images belonging to 2 classes.
# Found 1819 images belonging to 2 classes.

# %%
test_path = "test_dataset"

test_datagen = ImageDataGenerator(
      rescale = 1./255)
test_data = test_datagen.flow_from_directory(
	  test_path,
	  target_size=IMG_SIZE,
        shuffle=False,
        seed=9,
        class_mode = "categorical")
# Out:
# Found 1011 images belonging to 2 classes.

# %%
# get the class labels for the training data, in the original order 
train_labels = train_set1.classes 
 
# convert the training labels to categorical vectors 
train_labels = to_categorical(train_labels, num_classes=2)    

# get the class labels for the training data, in the original order 
test_labels = test_data.classes 
 
# convert the training labels to categorical vectors 
test_labels = to_categorical(test_labels, num_classes=2)

test_data.class_indices
# Out:
# {'btm': 0, 'top': 1}

# %%
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix

#To get better visual of the confusion matrix:
def plot_confusion_matrix(cm, classes,
   normalize=False,
   title='Confusion matrix',
   cmap=plt.cm.Blues):
 
#Add Normalization Option

   if normalize:
     cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
     print('Normalized confusion matrix')
   else:
     print('Confusion matrix, without normalization')
 
# print(cm)
 
   plt.imshow(cm, interpolation='nearest', cmap=cmap)
   plt.title(title)
   plt.colorbar()
   tick_marks = np.arange(len(classes))
   plt.xticks(tick_marks, classes, rotation=45)
   plt.yticks(tick_marks, classes)
 
   fmt = '.2f' if normalize else 'd'
   thresh = cm.max() / 2.
   for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt), horizontalalignment='center', color='white' if cm[i, j] > thresh else 'black')
 
   plt.tight_layout()
   plt.ylabel('True label')
   plt.xlabel('Predicted label')

# %%
EPOCHS = 50
INIT_LR = 1e-4

nets = 10
model_list = [0]*nets

for j in range(nets):
    print(f"Model {j}")
    model_list[j] = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=IMG_SIZE+(3,)),
        tf.keras.layers.MaxPooling2D(2, 2), 
        tf.keras.layers.Conv2D(64, (5,5), activation='relu'), 
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (5,5), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dense(2, activation='softmax') 
        ])
    model_list[j].compile(
        optimizer= tf.keras.optimizers.Adam(
        learning_rate=INIT_LR, 
        decay=INIT_LR / EPOCHS),
        loss=keras.losses.categorical_crossentropy,
        metrics=["accuracy"]
        )
    H1 = model_list[j].fit(
        train_set1, 
        epochs=20, 
        validation_data=val_set1
    )
    print(f"Finished training Model {j}")
print("All models trained")
# Out:
# Model 0
# Epoch 1/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.5820 - accuracy: 0.6939 - val_loss: 0.4454 - val_accuracy: 0.7955
# Epoch 2/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4957 - accuracy: 0.7768 - val_loss: 0.4099 - val_accuracy: 0.8186
# Epoch 3/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4309 - accuracy: 0.8063 - val_loss: 0.3749 - val_accuracy: 0.8417
# Epoch 4/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3962 - accuracy: 0.8280 - val_loss: 0.3527 - val_accuracy: 0.8455
# Epoch 5/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3662 - accuracy: 0.8443 - val_loss: 0.3210 - val_accuracy: 0.8582
# Epoch 6/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3583 - accuracy: 0.8474 - val_loss: 0.3064 - val_accuracy: 0.8681
# Epoch 7/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3462 - accuracy: 0.8543 - val_loss: 0.2996 - val_accuracy: 0.8719
# Epoch 8/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3429 - accuracy: 0.8558 - val_loss: 0.2930 - val_accuracy: 0.8752
# Epoch 9/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3257 - accuracy: 0.8598 - val_loss: 0.3083 - val_accuracy: 0.8659
# Epoch 10/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3282 - accuracy: 0.8597 - val_loss: 0.2825 - val_accuracy: 0.8807
# Epoch 11/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3073 - accuracy: 0.8698 - val_loss: 0.2755 - val_accuracy: 0.8873
# Epoch 12/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3061 - accuracy: 0.8708 - val_loss: 0.3284 - val_accuracy: 0.8642
# Epoch 13/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3044 - accuracy: 0.8753 - val_loss: 0.2865 - val_accuracy: 0.8807
# Epoch 14/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3022 - accuracy: 0.8740 - val_loss: 0.2705 - val_accuracy: 0.8944
# Epoch 15/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.2918 - accuracy: 0.8826 - val_loss: 0.2704 - val_accuracy: 0.8939
# Epoch 16/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2827 - accuracy: 0.8818 - val_loss: 0.2615 - val_accuracy: 0.8939
# Epoch 17/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.2829 - accuracy: 0.8882 - val_loss: 0.2948 - val_accuracy: 0.8752
# Epoch 18/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.2702 - accuracy: 0.8937 - val_loss: 0.2704 - val_accuracy: 0.8900
# Epoch 19/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.2700 - accuracy: 0.8888 - val_loss: 0.2696 - val_accuracy: 0.8961
# Epoch 20/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.2647 - accuracy: 0.8931 - val_loss: 0.2679 - val_accuracy: 0.8972
# Finished training Model 0
# Model 1
# Epoch 1/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.5857 - accuracy: 0.6959 - val_loss: 0.4556 - val_accuracy: 0.7999
# Epoch 2/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4841 - accuracy: 0.7769 - val_loss: 0.4411 - val_accuracy: 0.8202
# Epoch 3/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4352 - accuracy: 0.8047 - val_loss: 0.4402 - val_accuracy: 0.8021
# Epoch 4/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4032 - accuracy: 0.8221 - val_loss: 0.3615 - val_accuracy: 0.8373
# Epoch 5/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3801 - accuracy: 0.8345 - val_loss: 0.3147 - val_accuracy: 0.8609
# Epoch 6/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3565 - accuracy: 0.8458 - val_loss: 0.4550 - val_accuracy: 0.7938
# Epoch 7/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3467 - accuracy: 0.8535 - val_loss: 0.3625 - val_accuracy: 0.8450
# Epoch 8/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3336 - accuracy: 0.8576 - val_loss: 0.2826 - val_accuracy: 0.8829
# Epoch 9/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.3269 - accuracy: 0.8631 - val_loss: 0.2899 - val_accuracy: 0.8824
# Epoch 10/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.3161 - accuracy: 0.8674 - val_loss: 0.2884 - val_accuracy: 0.8796
# Epoch 11/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.3198 - accuracy: 0.8707 - val_loss: 0.3101 - val_accuracy: 0.8675
# Epoch 12/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.3085 - accuracy: 0.8718 - val_loss: 0.2898 - val_accuracy: 0.8829
# Epoch 13/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.3011 - accuracy: 0.8705 - val_loss: 0.2671 - val_accuracy: 0.8988
# Epoch 14/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2899 - accuracy: 0.8815 - val_loss: 0.2606 - val_accuracy: 0.9005
# Epoch 15/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2896 - accuracy: 0.8777 - val_loss: 0.2749 - val_accuracy: 0.8911
# Epoch 16/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2768 - accuracy: 0.8885 - val_loss: 0.2910 - val_accuracy: 0.8829
# Epoch 17/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2738 - accuracy: 0.8849 - val_loss: 0.2559 - val_accuracy: 0.9021
# Epoch 18/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2650 - accuracy: 0.8895 - val_loss: 0.3031 - val_accuracy: 0.8846
# Epoch 19/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2644 - accuracy: 0.8925 - val_loss: 0.2554 - val_accuracy: 0.9021
# Epoch 20/20
# 228/228 [==============================] - 453s 2s/step - loss: 0.2533 - accuracy: 0.8988 - val_loss: 0.2556 - val_accuracy: 0.8966
# Finished training Model 1
# Model 2
# Epoch 1/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.6003 - accuracy: 0.6836 - val_loss: 0.4992 - val_accuracy: 0.7768
# Epoch 2/20
# 228/228 [==============================] - 452s 2s/step - loss: 0.4917 - accuracy: 0.7732 - val_loss: 0.4075 - val_accuracy: 0.8186
# Epoch 3/20
# 228/228 [==============================] - 452s 2s/step - loss: 0
# Epoch 15/20
# 228/228 [==============================] - 461s 2s/step - loss: 0.2918 - accuracy: 0.8815 - val_loss: 0.2834 - val_accuracy: 0.8928
# Epoch 16/20
# 228/228 [==============================] - 461s 2s/step - loss: 0.2853 - accuracy: 0.8825 - val_loss: 0.2837 - val_accuracy: 0.8862
# Epoch 17/20
# 228/228 [==============================] - 461s 2s/step - loss: 0.2711 - accuracy: 0.8878 - val_loss: 0.2691 - val_accuracy: 0.8928
# Epoch 18/20
# 228/228 [==============================] - 462s 2s/step - loss: 0.2676 - accuracy: 0.8929 - val_loss: 0.2796 - val_accuracy: 0.8999
# Epoch 19/20
# 228/228 [==============================] - 462s 2s/step - loss: 0.2669 - accuracy: 0.8921 - val_loss: 0.2710 - val_accuracy: 0.8906
# Epoch 20/20
# 228/228 [==============================] - 461s 2s/step - loss: 0.2667 - accuracy: 0.8933 - val_loss: 0.2581 - val_accuracy: 0.9021
# Finished training Model 6
# Model 7
# Epoch 1/20
# 228/228 [==============================] - 470s 2s/step - loss: 0.6056 - accuracy: 0.6734 - val_loss: 0.4973 - val_accuracy: 0.7625
# Epoch 2/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.4928 - accuracy: 0.7717 - val_loss: 0.3869 - val_accuracy: 0.8329
# Epoch 3/20
# 228/228 [==============================] - 470s 2s/step - loss: 0.4306 - accuracy: 0.8066 - val_loss: 0.3604 - val_accuracy: 0.8549
# Epoch 4/20
# 228/228 [==============================] - 470s 2s/step - loss: 0.4044 - accuracy: 0.8232 - val_loss: 0.3583 - val_accuracy: 0.8477
# Epoch 5/20
# 228/228 [==============================] - 470s 2s/step - loss: 0.3750 - accuracy: 0.8403 - val_loss: 0.3491 - val_accuracy: 0.8384
# Epoch 6/20
# 228/228 [==============================] - 470s 2s/step - loss: 0.3584 - accuracy: 0.8471 - val_loss: 0.3439 - val_accuracy: 0.8494
# Epoch 7/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3529 - accuracy: 0.8444 - val_loss: 0.2984 - val_accuracy: 0.8807
# Epoch 8/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3373 - accuracy: 0.8579 - val_loss: 0.3172 - val_accuracy: 0.8620
# Epoch 9/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3352 - accuracy: 0.8597 - val_loss: 0.3115 - val_accuracy: 0.8719
# Epoch 10/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3287 - accuracy: 0.8610 - val_loss: 0.2859 - val_accuracy: 0.8796
# Epoch 11/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3159 - accuracy: 0.8667 - val_loss: 0.3076 - val_accuracy: 0.8824
# Epoch 12/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.3079 - accuracy: 0.8716 - val_loss: 0.2787 - val_accuracy: 0.8857
# Epoch 13/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.2967 - accuracy: 0.8773 - val_loss: 0.2747 - val_accuracy: 0.8922
# Epoch 14/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.2944 - accuracy: 0.8781 - val_loss: 0.2771 - val_accuracy: 0.8846
# Epoch 15/20
# 228/228 [==============================] - 471s 2s/step - loss: 0.2841 - accuracy: 0.8819 - val_loss: 0.2694 - val_accuracy: 0.8922
# Epoch 16/20
# 228/228 [==============================] - 474s 2s/step - loss: 0.2772 - accuracy: 0.8882 - val_loss: 0.2584 - val_accuracy: 0.9016
# Epoch 17/20
# 228/228 [==============================] - 478s 2s/step - loss: 0.2731 - accuracy: 0.8909 - val_loss: 0.2582 - val_accuracy: 0.8895
# Epoch 18/20
# 228/228 [==============================] - 478s 2s/step - loss: 0.2746 - accuracy: 0.8858 - val_loss: 0.2565 - val_accuracy: 0.8994
# Epoch 19/20
# 228/228 [==============================] - 478s 2s/step - loss: 0.2608 - accuracy: 0.8928 - val_loss: 0.2862 - val_accuracy: 0.8917
# Epoch 20/20
# 228/228 [==============================] - 479s 2s/step - loss: 0.2561 - accuracy: 0.8958 - val_loss: 0.2562 - val_accuracy: 0.8972
# Finished training Model 7
# Model 8
# Epoch 1/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.5786 - accuracy: 0.6972 - val_loss: 0.4711 - val_accuracy: 0.7598
# Epoch 2/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.4832 - accuracy: 0.7794 - val_loss: 0.4093 - val_accuracy: 0.8186
# Epoch 3/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.4332 - accuracy: 0.8088 - val_loss: 0.3571 - val_accuracy: 0.8395
# Epoch 4/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3980 - accuracy: 0.8263 - val_loss: 0.3284 - val_accuracy: 0.8642
# Epoch 5/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3827 - accuracy: 0.8366 - val_loss: 0.3170 - val_accuracy: 0.8642
# Epoch 6/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.3671 - accuracy: 0.8462 - val_loss: 0.3061 - val_accuracy: 0.8708
# Epoch 7/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3476 - accuracy: 0.8535 - val_loss: 0.2941 - val_accuracy: 0.8796
# Epoch 8/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3382 - accuracy: 0.8576 - val_loss: 0.2954 - val_accuracy: 0.8763
# Epoch 9/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3318 - accuracy: 0.8590 - val_loss: 0.2949 - val_accuracy: 0.8857
# Epoch 10/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3145 - accuracy: 0.8700 - val_loss: 0.2896 - val_accuracy: 0.8725
# Epoch 11/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3208 - accuracy: 0.8638 - val_loss: 0.2882 - val_accuracy: 0.8813
# Epoch 12/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.3084 - accuracy: 0.8701 - val_loss: 0.2694 - val_accuracy: 0.8857
# Epoch 13/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.3005 - accuracy: 0.8778 - val_loss: 0.3061 - val_accuracy: 0.8758
# Epoch 14/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.2892 - accuracy: 0.8801 - val_loss: 0.2678 - val_accuracy: 0.8977
# Epoch 15/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.2854 - accuracy: 0.8845 - val_loss: 0.2715 - val_accuracy: 0.8906
# Epoch 16/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.2838 - accuracy: 0.8847 - val_loss: 0.2678 - val_accuracy: 0.8977
# Epoch 17/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.2870 - accuracy: 0.8877 - val_loss: 0.2709 - val_accuracy: 0.9010
# Epoch 18/20
# 228/228 [==============================] - 480s 2s/step - loss: 0.2659 - accuracy: 0.8913 - val_loss: 0.2747 - val_accuracy: 0.8906
# Epoch 19/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.2592 - accuracy: 0.8937 - val_loss: 0.2636 - val_accuracy: 0.8983
# Epoch 20/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.2604 - accuracy: 0.8977 - val_loss: 0.2574 - val_accuracy: 0.9071
# Finished training Model 8
# Model 9
# Epoch 1/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.5756 - accuracy: 0.7072 - val_loss: 0.4930 - val_accuracy: 0.7867
# Epoch 2/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.4801 - accuracy: 0.7864 - val_loss: 0.3997 - val_accuracy: 0.8202
# Epoch 3/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.4222 - accuracy: 0.8132 - val_loss: 0.4093 - val_accuracy: 0.8131
# Epoch 4/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3943 - accuracy: 0.8290 - val_loss: 0.3221 - val_accuracy: 0.8615
# Epoch 5/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3803 - accuracy: 0.8395 - val_loss: 0.3213 - val_accuracy: 0.8703
# Epoch 6/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3598 - accuracy: 0.8445 - val_loss: 0.3199 - val_accuracy: 0.8642
# Epoch 7/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3555 - accuracy: 0.8489 - val_loss: 0.3159 - val_accuracy: 0.8626
# Epoch 8/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.3345 - accuracy: 0.8595 - val_loss: 0.3067 - val_accuracy: 0.8747
# Epoch 9/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3234 - accuracy: 0.8645 - val_loss: 0.2837 - val_accuracy: 0.8857
# Epoch 10/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3132 - accuracy: 0.8691 - val_loss: 0.3244 - val_accuracy: 0.8686
# Epoch 11/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3202 - accuracy: 0.8639 - val_loss: 0.3074 - val_accuracy: 0.8791
# Epoch 12/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3046 - accuracy: 0.8770 - val_loss: 0.2748 - val_accuracy: 0.8906
# Epoch 13/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2998 - accuracy: 0.8762 - val_loss: 0.2604 - val_accuracy: 0.8988
# Epoch 14/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.3039 - accuracy: 0.8759 - val_loss: 0.2752 - val_accuracy: 0.8955
# Epoch 15/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2801 - accuracy: 0.8811 - val_loss: 0.2568 - val_accuracy: 0.9010
# Epoch 16/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2821 - accuracy: 0.8848 - val_loss: 0.2773 - val_accuracy: 0.8944
# Epoch 17/20
# 228/228 [==============================] - 481s 2s/step - loss: 0.2721 - accuracy: 0.8892 - val_loss: 0.2663 - val_accuracy: 0.8906
# Epoch 18/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2661 - accuracy: 0.8892 - val_loss: 0.2553 - val_accuracy: 0.8961
# Epoch 19/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2672 - accuracy: 0.8914 - val_loss: 0.2612 - val_accuracy: 0.8988
# Epoch 20/20
# 228/228 [==============================] - 482s 2s/step - loss: 0.2544 - accuracy: 0.8986 - val_loss: 0.2704 - val_accuracy: 0.8895
# Finished training Model 9
# All models trained

# %%
for j in range(nets):
    fpath = f"ensemble_{j}.h5"
    model_list[j].save(fpath)

# %%
classificationlabels = ["top","btm"]
nets = 10
model_list = [0]*nets
for j in range(nets):
    model_list[j] = keras.models.load_model(f'ensemble_{j}.h5')

results = np.zeros( (X_test.shape[0],2) ) 
for j in range(nets):
    results = results + model_list[j].predict(test_data)
 
results = np.round(results,0)

final_results = np.zeros( (X_test.shape[0],2) )
final_results[np.arange(results.shape[0]),np.argmax(results, axis = 1)] = 1
final_results

classification_metrics = metrics.classification_report(test_labels, final_results, target_names=classificationlabels)

print(classification_metrics)
# Out:
#               precision    recall  f1-score   support
#
#          top       0.95      0.89      0.92       507
#          btm       0.89      0.95      0.92       504
#
#    micro avg       0.92      0.92      0.92      1011
#    macro avg       0.92      0.92      0.92      1011
# weighted avg       0.92      0.92      0.92      1011
#  samples avg       0.92      0.92      0.92      1011

# %%
categorical_test_labels = pd.DataFrame(test_labels).idxmax(axis=1)
categorical_preds2 = pd.DataFrame(final_results).idxmax(axis=1)
confusion_matrix3 = confusion_matrix(categorical_test_labels, categorical_preds2)


plot_confusion_matrix(confusion_matrix3, ['top','btm'])
# Out:
# Confusion matrix, without normalization
